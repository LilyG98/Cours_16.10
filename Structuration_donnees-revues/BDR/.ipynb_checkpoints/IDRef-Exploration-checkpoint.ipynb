# %% [markdown]
# # Pourquoi et comment
#
# **Objectif** : recueillir les pnn (càd les identifiants IdRef) des contributeurs à la revue.
#
# **Démarche** :
# 1) Structurer la des prénoms / noms avec colonnes "NOM"et "Prenom"
# 2) Générer l'url idRef pour chaque nom. paramètres utilisées:
#     *
# 3) Extraire le nbr d'occurences du nom
#
# **Documentation**: Recours à l'API SolR<a href = "http://documentation.abes.fr/aideidrefdeveloppeur/index.html"> abes </a>

# %%
import re
import pandas as pd
import csv
import numpy as np 
import requests
from bs4 import BeautifulSoup
import lxml

# %% [markdown]
# ## 1. Structurer la liste des nom/prénoms

# %%
with open ("../BSPE/Membres_SPE/Liste-Noms-Contributeurs.csv") as contributeurs:
    df_contributeurs = pd.read_csv(contributeurs)

# %%
df_contributeurs
# Out:
#          NOM (Prenom)
# 0        ACHALME (P.)
# 1           ADDE (R.)
# 2          AHMED (E.)
# 3          ALARY (A.)
# 4    ALLAIN (Jacques)
# ..                ...
# 658    YVERNAULT (A.)
# 659         YVON (P.)
# 660         ZABOLOTNY
# 661      ZAMMIT (TH.)
# 662        ZUCCARELLI
#
# [663 rows x 1 columns]

# %%
## Séparer NOM et Prénom : 

#Nouvelle colonne pour le NOM => .iloc[i,1]
df_contributeurs["NOM"] = df_contributeurs.apply(lambda _: '', axis=1)
#Nouvelle colonne pour le PRENOM => .iloc[i,2]
df_contributeurs["Prenom"] = df_contributeurs.apply(lambda _: '', axis=1)


#Regex NOM (Prénom)
reNom = r'([-\'A-zÀ-ÿ]+((-| |\’)[A-zÀ-ÿ]+)?)( \(.*)?'
rePrenom = r'\((.*)(\.)?\)'

for i in range(len(df_contributeurs)):
    
    df_contributeurs.iloc[i,1] = re.search(reNom,df_contributeurs.iloc[i,0]).group(1)
    Prenom = re.search(rePrenom,df_contributeurs.iloc[i,0])
    if Prenom:
        Prenom2=re.sub(r' {1,2}',"",Prenom.group(1))
        df_contributeurs.iloc[i,2]=Prenom2

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
# [663 rows x 3 columns]

# %%
df_contributeurs.iloc[158,1]
# Out:
# 'D’HÉRELLE'

# %% [markdown]
# ## 2. Générer les url idref et le entrer dans le df

# %%
#Ajout de colonnes au df pour les url. 
df_contributeurs = df_contributeurs.reindex(columns = df_contributeurs.columns.tolist() + ['Recherche_G_t','Recherche_NomPrenom_t'])
RechercheG = []
RechercheNOMPrenom =[]

# %%
for i in range(len(df_contributeurs)):
#     print(df_contributeurs.iloc[i,0])
    NOM=df_contributeurs.iloc[i,1]
    Prenom=df_contributeurs.iloc[i,2]
    
    #Paramétrage : 
    ## => recordtype_z :h (càd Auteur Titre)
    
    
    if re.search(r'(.*)' '(.*)',NOM):#Si nom composé. Ex : "DE MAURICOURT"
        NOM2=NOM.replace(' ','%20AND')
        
        if Prenom:

            #url générale:
            df_contributeurs.iloc[i,3]="https://www.idref.fr/Sru/Solr?q=persname_t:"+NOM2+"%20"+Prenom+"&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheG.append(df_contributeurs.iloc[i,3])

            #url NOM AND Prenom:
            df_contributeurs.iloc[i,4] ="https://www.idref.fr/Sru/Solr?q=persname_t:("+NOM2+"%20AND%20"+Prenom+")&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheNOMPrenom.append(df_contributeurs.iloc[i,4])
        
        else :
            #url générale:
            df_contributeurs.iloc[i,3]="https://www.idref.fr/Sru/Solr?q=persname_t:"+NOM2+"&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheG.append(df_contributeurs.iloc[i,3])
            
            #url NOM AND Prenom : 
            df_contributeurs.iloc[i,4] ="https://www.idref.fr/Sru/Solr?q=persname_t:("+NOM2+")&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheNOMPrenom.append(df_contributeurs.iloc[i,4])
    
    else :
        if Prenom:

            #url générale:
            df_contributeurs.iloc[i,3]="https://www.idref.fr/Sru/Solr?q=persname_t:"+NOM+"%20"+Prenom+"&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheG.append(df_contributeurs.iloc[i,3])

            #url NOM AND Prenom:
            df_contributeurs.iloc[i,4] ="https://www.idref.fr/Sru/Solr?q=persname_t:("+NOM+"%20AND%20"+Prenom+")&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheNOMPrenom.append(df_contributeurs.iloc[i,4])
        
        else :
            #url générale:
            df_contributeurs.iloc[i,3]="https://www.idref.fr/Sru/Solr?q=persname_t:"+NOM+"&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheG.append(df_contributeurs.iloc[i,3])
            
            #url NOM AND Prenom : 
            df_contributeurs.iloc[i,4] ="https://www.idref.fr/Sru/Solr?q=persname_t:("+NOM+")&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
            RechercheNOMPrenom.append(df_contributeurs.iloc[i,4])

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom  \
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
#                                          Recherche_G_t  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:ACH...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:ADD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:AHM...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:ALA...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:ALL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:YVE...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:YVO...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:ZAB...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:ZAM...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:ZUC...
#
#                                  Recherche_NomPrenom_t
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:(AC...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:(AD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:(AH...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:(ZU...
#
# [663 rows x 5 columns]

# %% [markdown]
# ## 3. Chercher s'il existe au moins une notice associée à l'url idref

# %% [markdown]
# Méthode : pour chaque url chercher la valeur de l'attribut numFound dans l'elt <result>
# \
# `<result name="response" numFound="0" start="0"/>`

# %%
df_contributeurs = df_contributeurs.reindex(columns = df_contributeurs.columns.tolist() + ['Recherche_G-nbr','Recherche_NomPrenom-nbr'])

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom  \
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
#                                          Recherche_G_t  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:ACH...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:ADD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:AHM...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:ALA...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:ALL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:YVE...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:YVO...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:ZAB...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:ZAM...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:ZUC...
#
#                                  Recherche_NomPrenom_t  Recherche_G-nbr  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:(AC...              NaN
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:(AD...              NaN
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:(AH...              NaN
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...              NaN
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...              NaN
# ..                                                 ...              ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...              NaN
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...              NaN
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...              NaN
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...              NaN
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:(ZU...              NaN
#
#      Recherche_NomPrenom-nbr
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 658                      NaN
# 659                      NaN
# 660                      NaN
# 661                      NaN
# 662                      NaN
#
# [663 rows x 7 columns]

# %% [markdown]
# # 3. Extraire le nombre d'occurences du nom selon le type de recherche

# %%
def IdRef_numfound_auteur (col):
    list_numfound_IdRef = []

    for url in col:
        r = requests.get(url)
        xml = r.text
        #print(r.text)

        soup = BeautifulSoup(xml,'lxml')
        eltResult = soup.find_all('result')

        for att in eltResult:
            attnumFound = att.get("numfound")

        list_numfound_IdRef.append(attnumFound)
    
    return list_numfound_IdRef

#<result name="response" numFound="0" start="0"/>

# %%
col = df_contributeurs["Recherche_G_t"]
df_contributeurs["Recherche_G-nbr"] = IdRef_numfound_auteur(col)

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom  \
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
#                                          Recherche_G_t  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:ACH...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:ADD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:AHM...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:ALA...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:ALL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:YVE...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:YVO...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:ZAB...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:ZAM...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:ZUC...
#
#                                  Recherche_NomPrenom_t Recherche_G-nbr  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:(AC...               4
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:(AD...              27
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:(AH...            3627
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...              77
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...             364
# ..                                                 ...             ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...              16
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...             854
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...               2
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...              33
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:(ZU...              25
#
#      Recherche_NomPrenom-nbr
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 658                      NaN
# 659                      NaN
# 660                      NaN
# 661                      NaN
# 662                      NaN
#
# [663 rows x 7 columns]

# %%
df_contributeurs.iloc[2,4]
# Out:
# 'https://www.idref.fr/Sru/Solr?q=persname_t:(AHMED%20AND%20E.)&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z'

# %%
col = df_contributeurs["Recherche_NomPrenom_t"]
df_contributeurs["Recherche_NomPrenom-nbr"] = IdRef_numfound_auteur(col)

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom  \
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
#                                          Recherche_G_t  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:ACH...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:ADD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:AHM...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:ALA...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:ALL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:YVE...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:YVO...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:ZAB...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:ZAM...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:ZUC...
#
#                                  Recherche_NomPrenom_t Recherche_G-nbr  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:(AC...               4
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:(AD...              27
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:(AH...            3627
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...              77
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...             364
# ..                                                 ...             ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...              16
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...             854
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...               2
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...              33
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:(ZU...              25
#
#     Recherche_NomPrenom-nbr
# 0                         0
# 1                         0
# 2                        15
# 3                         0
# 4                         5
# ..                      ...
# 658                       0
# 659                       4
# 660                       2
# 661                       0
# 662                      25
#
# [663 rows x 7 columns]

# %%
df_contributeurs.max()
# Out:
# NOM (Prenom)                                                      ZUCCARELLI
# NOM                                                               ZUCCARELLI
# Prenom                                                                   ÉT.
# Recherche_G_t              https://www.idref.fr/Sru/Solr?q=persname_t:ZUC...
# Recherche_NomPrenom_t      https://www.idref.fr/Sru/Solr?q=persname_t:(ZU...
# Recherche_G-nbr                                                        99084
# Recherche_NomPrenom-nbr                                                99085
# dtype: object

# %%
df_contributeurs.to_csv("IdRef_BSPE.tsv", sep="\t")

# %%
df_contributeurs.describe()
# Out:
#        NOM (Prenom)      NOM Prenom  \
# count           663      663    663
# unique          657      596    152
# top      HENRY (A.)  CLAPIER     A.
# freq              2        4     86
#
#                                             Recherche_G_t  \
# count                                                 663
# unique                                                656
# top     https://www.idref.fr/Sru/Solr?q=persname_t:KER...
# freq                                                    2
#
#                                     Recherche_NomPrenom_t Recherche_G-nbr  \
# count                                                 663             663
# unique                                                656             250
# top     https://www.idref.fr/Sru/Solr?q=persname_t:(MA...               0
# freq                                                    2              56
#
#        Recherche_NomPrenom-nbr
# count                      663
# unique                      69
# top                          0
# freq                       378

# %%
df_contributeurs["Recherche_G-nbr"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-fa6e1978760e> in <module>
# ----> 1 df_contributeurs["Recherche_G-nbr"].plot()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %% [markdown]
# # 4. Exploration des résultats

# %% [markdown]
# ## Groupby : NOM(Prenom)

# %%
df_NP=df_contributeurs.groupby(by="NOM (Prenom)").count()

# %%
df_NP
# Out:
#                   NOM  Prenom  Recherche_G_t  Recherche_NomPrenom_t  \
# NOM (Prenom)
# ACHALME (P.)        1       1              1                      1
# ADDE (R.)           1       1              1                      1
# AHMED (E.)          1       1              1                      1
# ALARY (A.)          1       1              1                      1
# ALLAIN (Jacques)    1       1              1                      1
# ...               ...     ...            ...                    ...
# YVERNAULT (A.)      1       1              1                      1
# YVON (P.)           1       1              1                      1
# ZABOLOTNY           1       1              1                      1
# ZAMMIT (TH.)        1       1              1                      1
# ZUCCARELLI          1       1              1                      1
#
#                   Recherche_G-nbr  Recherche_NomPrenom-nbr
# NOM (Prenom)
# ACHALME (P.)                    1                        1
# ADDE (R.)                       1                        1
# AHMED (E.)                      1                        1
# ALARY (A.)                      1                        1
# ALLAIN (Jacques)                1                        1
# ...                           ...                      ...
# YVERNAULT (A.)                  1                        1
# YVON (P.)                       1                        1
# ZABOLOTNY                       1                        1
# ZAMMIT (TH.)                    1                        1
# ZUCCARELLI                      1                        1
#
# [657 rows x 6 columns]

# %% [markdown]
# ### A) Pour l'url "générale"

# %%
#Le maximum d'occurences d'un même nom est de 99.061
#On  535 noms de personnes qui n'apparaissent pas dans IdRef

print("le maximum d'occurences pour un même url IdRef est : ",df_contributeurs["Recherche_G-nbr"].max())
df_G=df_contributeurs.groupby(by="Recherche_G-nbr").count()
# Out:
# le maximum d'occurences pour un même url IdRef est :  99084

# %%
df_G.sort_values(by="NOM")
df_G.sort_index ## ON voit que seuls 90 noms parai
# Out:
# <bound method DataFrame.sort_index of                  NOM (Prenom)  NOM  Prenom  Recherche_G_t  \
# Recherche_G-nbr
# 0                          56   56      56             56
# 1                          26   26      26             26
# 10                          8    8       8              8
# 101                         2    2       2              2
# 10124                       2    2       2              2
# ...                       ...  ...     ...            ...
# 961                         1    1       1              1
# 964                         1    1       1              1
# 9723                        1    1       1              1
# 99                          2    2       2              2
# 99084                       5    5       5              5
#
#                  Recherche_NomPrenom_t  Recherche_NomPrenom-nbr
# Recherche_G-nbr
# 0                                   56                       56
# 1                                   26                       26
# 10                                   8                        8
# 101                                  2                        2
# 10124                                2                        2
# ...                                ...                      ...
# 961                                  1                        1
# 964                                  1                        1
# 9723                                 1                        1
# 99                                   2                        2
# 99084                                5                        5
#
# [250 rows x 6 columns]>

# %%
df_G.describe()
# Out:
#        NOM (Prenom)         NOM      Prenom  Recherche_G_t  \
# count    250.000000  250.000000  250.000000     250.000000
# mean       2.652000    2.652000    2.652000       2.652000
# std        4.940905    4.940905    4.940905       4.940905
# min        1.000000    1.000000    1.000000       1.000000
# 25%        1.000000    1.000000    1.000000       1.000000
# 50%        1.000000    1.000000    1.000000       1.000000
# 75%        2.000000    2.000000    2.000000       2.000000
# max       56.000000   56.000000   56.000000      56.000000
#
#        Recherche_NomPrenom_t  Recherche_NomPrenom-nbr
# count             250.000000               250.000000
# mean                2.652000                 2.652000
# std                 4.940905                 4.940905
# min                 1.000000                 1.000000
# 25%                 1.000000                 1.000000
# 50%                 1.000000                 1.000000
# 75%                 2.000000                 2.000000
# max                56.000000                56.000000

# %%
df_G_zero=df_contributeurs.loc[df_contributeurs["Recherche_G-nbr"] == "0"]

df_G_zero
# Out:
#                    NOM (Prenom)                   NOM     Prenom  \
# 5    ANDREANI-CONSTANTINI (MME)  ANDREANI-CONSTANTINI        MME
# 8              ARAVANDINOS (A.)           ARAVANDINOS         A.
# 38              BEKENSKY (P.W.)              BEKENSKY       P.W.
# 39              BELITZER (A.W.)              BELITZER       A.W.
# 64                   BONNEFAY()              BONNEFAY
# 106                   CAMBILLET             CAMBILLET
# 107         CAMINOPETROS (JEAN)          CAMINOPETROS       JEAN
# 145                COUENDI (M.)               COUENDI         M.
# 153                CROVERI (P.)               CROVERI         P.
# 171           DEADERICK (W. H.)             DEADERICK       W.H.
# 173               DEGOUILLON ()            DEGOUILLON
# 178              DENARNAUX (P.)             DENARNAUX         P.
# 179              DENAVELLE (P.)             DENAVELLE         P.
# 186       DOMINICI-URBANI (CH.)       DOMINICI-URBANI        CH.
# 195              DUKODGEHÉ (W.)             DUKODGEHÉ         W.
# 237               GONZALEZ-LUGO         GONZALEZ-LUGO
# 271                JAVELLY (E.)               JAVELLY         E.
# 283               KÉRANDEL (J.)              KÉRANDEL         J.
# 284       KERMOGANT (Alexandre)             KERMOGANT  Alexandre
# 285       KERMOGANT (Alexandre)             KERMOGANT  Alexandre
# 288     KIWTET DE JONGE (G.-H.)             KIWTET DE      G.-H.
# 289           KOBNILOFF (M.-I.)             KOBNILOFF      M.-I.
# 290        KOHL-YAKIMOFF (Nina)         KOHL-YAKIMOFF       Nina
# 291           KOLPAKOFF (F.-A.)             KOLPAKOFF      F.-A.
# 292           KOLPAKOFF (T.-A.)             KOLPAKOFF      T.-A.
# 295           KOSELKINE (P.-M.)             KOSELKINE      P.-M.
# 296                   KOULECHIA             KOULECHIA
# 298            KROLUNITZKI (G.)           KROLUNITZKI         G.
# 309        LALUNG-BONNAIRE (P.)       LALUNG-BONNAIRE         P.
# 358            MANGENIE (S -E.)              MANGENIE       S-E.
# 374         MARZINOWSKY (E.-I.)           MARZINOWSKY      E.-I.
# 375         MARZINOWSKY (E.-J.)           MARZINOWSKY      E.-J.
# 387             MELISSIDIS (A.)            MELISSIDIS         A.
# 390             MESINCESCU (D.)            MESINCESCU         D.
# 396                MIGLIANO (L)              MIGLIANO          L
# 418                MOUZELS (P.)               MOUZELS         P.
# 436             NOWIKOFF (P.A.)              NOWIKOFF       P.A.
# 439                   OLDT (F.)                  OLDT         F.
# 446                   PAMARET()               PAMARET
# 448               PARFENTJEV ()            PARFENTJEV
# 449             PAROÏSKY (P.S.)              PAROÏSKY       P.S.
# 464              PHINGAULT (E.)             PHINGAULT         E.
# 489               QUARELLI (G.)              QUARELLI         G.
# 522                ROUDSKY (D.)               ROUDSKY         D.
# 531                      RUDRER                RUDRER
# 548       SAPHRONOWITSCH (R.A.)        SAPHRONOWITSCH       R.A.
# 555              SCHIRWIND (S.)             SCHIRWIND         S.
# 558            SCHOKHOR (N.-J.)              SCHOKHOR      N.-J.
# 563              SÉGUINAUD (J.)             SÉGUINAUD         J.
# 574           SOLOWZOFF (A.-S.)             SOLOWZOFF      A.-S.
# 589            TASHIM (Ibrahim)                TASHIM    Ibrahim
# 641                  WACON (P.)                 WACON         P.
# 644          WASSILEWSKY (W.J.)           WASSILEWSKY       W.J.
# 652            YAKIMOFF (A.-S.)              YAKIMOFF      A.-S.
# 653            YAKIMOFF (W -L )              YAKIMOFF        W-L
# 654                    YAKOBLEW              YAKOBLEW
#
#                                          Recherche_G_t  \
# 5    https://www.idref.fr/Sru/Solr?q=persname_t:AND...
# 8    https://www.idref.fr/Sru/Solr?q=persname_t:ARA...
# 38   https://www.idref.fr/Sru/Solr?q=persname_t:BEK...
# 39   https://www.idref.fr/Sru/Solr?q=persname_t:BEL...
# 64   https://www.idref.fr/Sru/Solr?q=persname_t:BON...
# 106  https://www.idref.fr/Sru/Solr?q=persname_t:CAM...
# 107  https://www.idref.fr/Sru/Solr?q=persname_t:CAM...
# 145  https://www.idref.fr/Sru/Solr?q=persname_t:COU...
# 153  https://www.idref.fr/Sru/Solr?q=persname_t:CRO...
# 171  https://www.idref.fr/Sru/Solr?q=persname_t:DEA...
# 173  https://www.idref.fr/Sru/Solr?q=persname_t:DEG...
# 178  https://www.idref.fr/Sru/Solr?q=persname_t:DEN...
# 179  https://www.idref.fr/Sru/Solr?q=persname_t:DEN...
# 186  https://www.idref.fr/Sru/Solr?q=persname_t:DOM...
# 195  https://www.idref.fr/Sru/Solr?q=persname_t:DUK...
# 237  https://www.idref.fr/Sru/Solr?q=persname_t:GON...
# 271  https://www.idref.fr/Sru/Solr?q=persname_t:JAV...
# 283  https://www.idref.fr/Sru/Solr?q=persname_t:KÉR...
# 284  https://www.idref.fr/Sru/Solr?q=persname_t:KER...
# 285  https://www.idref.fr/Sru/Solr?q=persname_t:KER...
# 288  https://www.idref.fr/Sru/Solr?q=persname_t:KIW...
# 289  https://www.idref.fr/Sru/Solr?q=persname_t:KOB...
# 290  https://www.idref.fr/Sru/Solr?q=persname_t:KOH...
# 291  https://www.idref.fr/Sru/Solr?q=persname_t:KOL...
# 292  https://www.idref.fr/Sru/Solr?q=persname_t:KOL...
# 295  https://www.idref.fr/Sru/Solr?q=persname_t:KOS...
# 296  https://www.idref.fr/Sru/Solr?q=persname_t:KOU...
# 298  https://www.idref.fr/Sru/Solr?q=persname_t:KRO...
# 309  https://www.idref.fr/Sru/Solr?q=persname_t:LAL...
# 358  https://www.idref.fr/Sru/Solr?q=persname_t:MAN...
# 374  https://www.idref.fr/Sru/Solr?q=persname_t:MAR...
# 375  https://www.idref.fr/Sru/Solr?q=persname_t:MAR...
# 387  https://www.idref.fr/Sru/Solr?q=persname_t:MEL...
# 390  https://www.idref.fr/Sru/Solr?q=persname_t:MES...
# 396  https://www.idref.fr/Sru/Solr?q=persname_t:MIG...
# 418  https://www.idref.fr/Sru/Solr?q=persname_t:MOU...
# 436  https://www.idref.fr/Sru/Solr?q=persname_t:NOW...
# 439  https://www.idref.fr/Sru/Solr?q=persname_t:OLD...
# 446  https://www.idref.fr/Sru/Solr?q=persname_t:PAM...
# 448  https://www.idref.fr/Sru/Solr?q=persname_t:PAR...
# 449  https://www.idref.fr/Sru/Solr?q=persname_t:PAR...
# 464  https://www.idref.fr/Sru/Solr?q=persname_t:PHI...
# 489  https://www.idref.fr/Sru/Solr?q=persname_t:QUA...
# 522  https://www.idref.fr/Sru/Solr?q=persname_t:ROU...
# 531  https://www.idref.fr/Sru/Solr?q=persname_t:RUD...
# 548  https://www.idref.fr/Sru/Solr?q=persname_t:SAP...
# 555  https://www.idref.fr/Sru/Solr?q=persname_t:SCH...
# 558  https://www.idref.fr/Sru/Solr?q=persname_t:SCH...
# 563  https://www.idref.fr/Sru/Solr?q=persname_t:SÉG...
# 574  https://www.idref.fr/Sru/Solr?q=persname_t:SOL...
# 589  https://www.idref.fr/Sru/Solr?q=persname_t:TAS...
# 641  https://www.idref.fr/Sru/Solr?q=persname_t:WAC...
# 644  https://www.idref.fr/Sru/Solr?q=persname_t:WAS...
# 652  https://www.idref.fr/Sru/Solr?q=persname_t:YAK...
# 653  https://www.idref.fr/Sru/Solr?q=persname_t:YAK...
# 654  https://www.idref.fr/Sru/Solr?q=persname_t:YAK...
#
#                                  Recherche_NomPrenom_t Recherche_G-nbr  \
# 5    https://www.idref.fr/Sru/Solr?q=persname_t:(AN...               0
# 8    https://www.idref.fr/Sru/Solr?q=persname_t:(AR...               0
# 38   https://www.idref.fr/Sru/Solr?q=persname_t:(BE...               0
# 39   https://www.idref.fr/Sru/Solr?q=persname_t:(BE...               0
# 64   https://www.idref.fr/Sru/Solr?q=persname_t:(BO...               0
# 106  https://www.idref.fr/Sru/Solr?q=persname_t:(CA...               0
# 107  https://www.idref.fr/Sru/Solr?q=persname_t:(CA...               0
# 145  https://www.idref.fr/Sru/Solr?q=persname_t:(CO...               0
# 153  https://www.idref.fr/Sru/Solr?q=persname_t:(CR...               0
# 171  https://www.idref.fr/Sru/Solr?q=persname_t:(DE...               0
# 173  https://www.idref.fr/Sru/Solr?q=persname_t:(DE...               0
# 178  https://www.idref.fr/Sru/Solr?q=persname_t:(DE...               0
# 179  https://www.idref.fr/Sru/Solr?q=persname_t:(DE...               0
# 186  https://www.idref.fr/Sru/Solr?q=persname_t:(DO...               0
# 195  https://www.idref.fr/Sru/Solr?q=persname_t:(DU...               0
# 237  https://www.idref.fr/Sru/Solr?q=persname_t:(GO...               0
# 271  https://www.idref.fr/Sru/Solr?q=persname_t:(JA...               0
# 283  https://www.idref.fr/Sru/Solr?q=persname_t:(KÉ...               0
# 284  https://www.idref.fr/Sru/Solr?q=persname_t:(KE...               0
# 285  https://www.idref.fr/Sru/Solr?q=persname_t:(KE...               0
# 288  https://www.idref.fr/Sru/Solr?q=persname_t:(KI...               0
# 289  https://www.idref.fr/Sru/Solr?q=persname_t:(KO...               0
# 290  https://www.idref.fr/Sru/Solr?q=persname_t:(KO...               0
# 291  https://www.idref.fr/Sru/Solr?q=persname_t:(KO...               0
# 292  https://www.idref.fr/Sru/Solr?q=persname_t:(KO...               0
# 295  https://www.idref.fr/Sru/Solr?q=persname_t:(KO...               0
# 296  https://www.idref.fr/Sru/Solr?q=persname_t:(KO...               0
# 298  https://www.idref.fr/Sru/Solr?q=persname_t:(KR...               0
# 309  https://www.idref.fr/Sru/Solr?q=persname_t:(LA...               0
# 358  https://www.idref.fr/Sru/Solr?q=persname_t:(MA...               0
# 374  https://www.idref.fr/Sru/Solr?q=persname_t:(MA...               0
# 375  https://www.idref.fr/Sru/Solr?q=persname_t:(MA...               0
# 387  https://www.idref.fr/Sru/Solr?q=persname_t:(ME...               0
# 390  https://www.idref.fr/Sru/Solr?q=persname_t:(ME...               0
# 396  https://www.idref.fr/Sru/Solr?q=persname_t:(MI...               0
# 418  https://www.idref.fr/Sru/Solr?q=persname_t:(MO...               0
# 436  https://www.idref.fr/Sru/Solr?q=persname_t:(NO...               0
# 439  https://www.idref.fr/Sru/Solr?q=persname_t:(OL...               0
# 446  https://www.idref.fr/Sru/Solr?q=persname_t:(PA...               0
# 448  https://www.idref.fr/Sru/Solr?q=persname_t:(PA...               0
# 449  https://www.idref.fr/Sru/Solr?q=persname_t:(PA...               0
# 464  https://www.idref.fr/Sru/Solr?q=persname_t:(PH...               0
# 489  https://www.idref.fr/Sru/Solr?q=persname_t:(QU...               0
# 522  https://www.idref.fr/Sru/Solr?q=persname_t:(RO...               0
# 531  https://www.idref.fr/Sru/Solr?q=persname_t:(RU...               0
# 548  https://www.idref.fr/Sru/Solr?q=persname_t:(SA...               0
# 555  https://www.idref.fr/Sru/Solr?q=persname_t:(SC...               0
# 558  https://www.idref.fr/Sru/Solr?q=persname_t:(SC...               0
# 563  https://www.idref.fr/Sru/Solr?q=persname_t:(SÉ...               0
# 574  https://www.idref.fr/Sru/Solr?q=persname_t:(SO...               0
# 589  https://www.idref.fr/Sru/Solr?q=persname_t:(TA...               0
# 641  https://www.idref.fr/Sru/Solr?q=persname_t:(WA...               0
# 644  https://www.idref.fr/Sru/Solr?q=persname_t:(WA...               0
# 652  https://www.idref.fr/Sru/Solr?q=persname_t:(YA...               0
# 653  https://www.idref.fr/Sru/Solr?q=persname_t:(YA...               0
# 654  https://www.idref.fr/Sru/Solr?q=persname_t:(YA...               0
#
#     Recherche_NomPrenom-nbr
# 5                         0
# 8                         0
# 38                        0
# 39                        0
# 64                        0
# 106                       0
# 107                       0
# 145                       0
# 153                       0
# 171                       0
# 173                       0
# 178                       0
# 179                       0
# 186                       0
# 195                       0
# 237                       0
# 271                       0
# 283                       0
# 284                       0
# 285                       0
# 288                       0
# 289                       0
# 290                       0
# 291                       0
# 292                       0
# 295                       0
# 296                       0
# 298                       0
# 309                       0
# 358                       0
# 374                       0
# 375                       0
# 387                       0
# 390                       0
# 396                       0
# 418                       0
# 436                       0
# 439                       0
# 446                       0
# 448                       0
# 449                       0
# 464                       0
# 489                       0
# 522                       0
# 531                       0
# 548                       0
# 555                       0
# 558                       0
# 563                       0
# 574                       0
# 589                       0
# 641                       0
# 644                       0
# 652                       0
# 653                       0
# 654                       0

# %%
#Nbr d'absence d'occurence:
df_G_zero.size #300 / 1500
# Out:
# 392

# %%
df_G.count(0)
# Out:
# NOM (Prenom)               250
# NOM                        250
# Prenom                     250
# Recherche_G_t              250
# Recherche_NomPrenom_t      250
# Recherche_NomPrenom-nbr    250
# dtype: int64

# %%
df_G.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### B) Pour l'url "NOMPrenom"

# %%
groups =df_contributeurs.groupby(by="Recherche_NomPrenom-nbr")

# %%
groups.count() #Seulement 69 types d'occurences différentes
# Out:
#                          NOM (Prenom)  NOM  Prenom  Recherche_G_t  \
# Recherche_NomPrenom-nbr
# 0                                 378  378     378            378
# 1                                 103  103     103            103
# 10                                  6    6       6              6
# 10124                               1    1       1              1
# 11                                  7    7       7              7
# ...                               ...  ...     ...            ...
# 81                                  1    1       1              1
# 810                                 1    1       1              1
# 83                                  1    1       1              1
# 9                                   6    6       6              6
# 99085                               1    1       1              1
#
#                          Recherche_NomPrenom_t  Recherche_G-nbr
# Recherche_NomPrenom-nbr
# 0                                          378              378
# 1                                          103              103
# 10                                           6                6
# 10124                                        1                1
# 11                                           7                7
# ...                                        ...              ...
# 81                                           1                1
# 810                                          1                1
# 83                                           1                1
# 9                                            6                6
# 99085                                        1                1
#
# [69 rows x 6 columns]
