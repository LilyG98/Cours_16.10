# %% [markdown]
# # Pourquoi et comment
#
# **Objectif** : recueillir les pnn (càd les identifiants IdRef) des contributeurs à la revue.
#
# **Démarche** :
# 1) Avec des auteurs du BSPE : faire une estimation du nombre de noms qui manquent.
# 2)
# 3)
#
# **Documentation**: Recours à l'API SolR<a href = "http://documentation.abes.fr/aideidrefdeveloppeur/index.html"> abes </a>

# %%
import re
import pandas as pd
import numpy as np 
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## 1. Structurer la liste des nom/prénoms

# %%
with open ("../BSPE/Membres_SPE/Liste-Noms-Contributeurs.csv") as contributeurs:
    df_contributeurs = pd.read_csv(contributeurs)

# %%
df_contributeurs
# Out:
#          NOM (Prenom)
# 0        ACHALME (P.)
# 1           ADDE (R.)
# 2          AHMED (E.)
# 3          ALARY (A.)
# 4    ALLAIN (Jacques)
# ..                ...
# 658    YVERNAULT (A.)
# 659         YVON (P.)
# 660         ZABOLOTNY
# 661      ZAMMIT (TH.)
# 662        ZUCCARELLI
#
# [663 rows x 1 columns]

# %%
## Séparer NOM et Prénom : 

#Nouvelle colonne pour le NOM => .iloc[i,1]
df_contributeurs["NOM"] = df_contributeurs.apply(lambda _: '', axis=1)
#Nouvelle colonne pour le PRENOM => .iloc[i,2]
df_contributeurs["Prenom"] = df_contributeurs.apply(lambda _: '', axis=1)


#Regex NOM (Prénom)
reNom = r'(^[A-Z]+)'
rePrenom = r'\((.*)\)'

for i in range(len(df_contributeurs)):
    df_contributeurs.iloc[i,1] = re.search(reNom,df_contributeurs.iloc[i,0]).group(1)
    Prenom = re.search(rePrenom,df_contributeurs.iloc[i,0])
    if Prenom:
        Prenom2=re.sub(r' {1,2}',"",Prenom.group(1))
        df_contributeurs.iloc[i,2]=Prenom2

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
# [663 rows x 3 columns]

# %% [markdown]
# ## 2. Générer les url idref et le entrer dans le df

# %%
#Ajout de colonnes au df pour les url. 
df_contributeurs = df_contributeurs.reindex(columns = df_contributeurs.columns.tolist() + ['Recherche_G','Recherche_NomPrenom'])
RechercheG = []
RechercheNOMPrenom =[]

# %%
for i in range(len(df_contributeurs)):
#     print(df_contributeurs.iloc[i,0])
    NOM=df_contributeurs.iloc[i,1]
    Prenom=df_contributeurs.iloc[i,2]
    
    #Paramétrage : 
    ## => recordtype_z :h (càd Auteur Titre)
    
    #url générale:
    df_contributeurs.iloc[i,3]="https://www.idref.fr/Sru/Solr?q=persname_t:"+NOM+Prenom+"&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
    RechercheG.append(df_contributeurs.iloc[i,3])
    
    #url NOM Prenom : 
    df_contributeurs.iloc[i,4] ="https://www.idref.fr/Sru/Solr?q=persname_t:("+NOM+"AND"+Prenom+")&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z"
    RechercheNOMPrenom.append(df_contributeurs.iloc[i,4])

# %%
df_contributeurs
# Out:
#          NOM (Prenom)         NOM   Prenom  \
# 0        ACHALME (P.)     ACHALME       P.
# 1           ADDE (R.)        ADDE       R.
# 2          AHMED (E.)       AHMED       E.
# 3          ALARY (A.)       ALARY       A.
# 4    ALLAIN (Jacques)      ALLAIN  Jacques
# ..                ...         ...      ...
# 658    YVERNAULT (A.)   YVERNAULT       A.
# 659         YVON (P.)        YVON       P.
# 660         ZABOLOTNY   ZABOLOTNY
# 661      ZAMMIT (TH.)      ZAMMIT      TH.
# 662        ZUCCARELLI  ZUCCARELLI
#
#                                            Recherche_G  \
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:ACH...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:ADD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:AHM...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:ALA...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:ALL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:YVE...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:YVO...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:ZAB...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:ZAM...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:ZUC...
#
#                                    Recherche_NomPrenom
# 0    https://www.idref.fr/Sru/Solr?q=persname_t:(AC...
# 1    https://www.idref.fr/Sru/Solr?q=persname_t:(AD...
# 2    https://www.idref.fr/Sru/Solr?q=persname_t:(AH...
# 3    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...
# 4    https://www.idref.fr/Sru/Solr?q=persname_t:(AL...
# ..                                                 ...
# 658  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...
# 659  https://www.idref.fr/Sru/Solr?q=persname_t:(YV...
# 660  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...
# 661  https://www.idref.fr/Sru/Solr?q=persname_t:(ZA...
# 662  https://www.idref.fr/Sru/Solr?q=persname_t:(ZU...
#
# [663 rows x 5 columns]

# %%
# Out:
# ['https://www.idref.fr/Sru/Solr?q=persname_t:ACHALMEP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ADDER.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:AHMEDE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ALARYA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ALLAINJacques&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ANDREANIMME&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ANFREVILLELéonD’&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ANTOINE&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARAVANDINOSA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARDOINE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARGAUDR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARIASJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARLOJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARROUX&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ARZTL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ATHIASG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:AUBERTP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:AUDAINL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:AUGJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BABAULTG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BACMANNA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BADER&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BALFOURA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BALOZETL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BARROISTH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BARTETA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BARTET&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BASILEC.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BAUCHEJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BAUJEANR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BAUVALLETH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BAYEUXR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BAZIN&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BAZINR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BEAUJEANR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:B&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BEGUETM.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BEGUET&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BEKENSKYP.W.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BELITZERA.W.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BELLETE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BELLEVALG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BENAZETL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BENOIT&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BEQUAERTJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BERNARDP.NOËL&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BERTRANDLouis-Edmond&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BETTENCOURTA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BIENASSISE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BIJONR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BILLETA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BILLIEMAZA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BIOTR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BIZARD&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLAIZOTL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLANCG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLANCGEORGES&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLANCHARDCamille&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLANCHARDM.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLANCHARDRaphael&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLANQUIERH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BLING.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BODET&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BONAINC.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BONNEFAY&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BONNETA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOQUETA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BORGESI.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BORIESL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BORRELA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOSSAVYF.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOTELHOC.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOTREAU&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUCHERHumbert&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUETG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUFFARDGustave&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUILLIEZM.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUINA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUQUETH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOURRAGUN.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOURRETG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUTINP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BOUVIERJ.E.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRAUP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRAULTJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRESSONP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRIDREJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRIMONTE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BROCHARDV.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BRODENA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BROQUETC.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:BROQUETCH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:
sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:LANGERONMAURICE&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:LANZENBERGA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:LAPIN&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
# ...
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SCHOKHORN.-J.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SCHWETZJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SCORDOF.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SCOTTW.-M.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SEGUINDQ&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SEGUYE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SENEVETG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SERGENTEDMOND&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SERGENTETIENNE&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SERGENTÉT.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SIMONDP.-L.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SIMONINJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SKRJABINK.-J.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SLATINEANOA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SMILLIEWILSONG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SOLOWZOFFA.-S.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SORELF.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SORIAP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SOULIH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SPAGNUOLOV.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SPENCERD.-B.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SPLENDOREA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:STANESCOV.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:STEFKOW.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:STL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:STRONGR.P.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SULDEYE.-W.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SURCOUFJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SWAMINATHG.S.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:SWELLENGREBELN.-H.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TASHIMIbrahim&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TEISSONNIEREM.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TEJERAE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TENDRONE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TEPPAZA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TEPPAZL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:THEILERA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:THJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:THIROUXA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:THOMSOND.B.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TODDJOHN-L.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TOUIN&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TOURNAIREP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TOURNIERE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TOURNIERELIE&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TRAUTMANNR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TRIBAUDEAUJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TRIBONDEAUL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TRIBOUTA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TRILLAT&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TROUETTEG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:TROUSSAINT&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ULBRICHH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:URBAING.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VAILLANTL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VAILLARD&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VALLETG.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VALLIN&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VANF.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VANL.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VANR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VANDENBRANDENF.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VASSALJ.J.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VEILLONA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VELUA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VELUH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VERDUNP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VERNESA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIALATTEC.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIALATTECH&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIENNEM.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIGNEP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIGUIERA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VILLENEUVE&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VILLENEUVEJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VINCENT&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VINCENTH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIOLLEH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIOLLER.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VISENTINIA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VIVIEN&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:VONE.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WACONP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WAGON&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WAGONP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WASSILEWSKYW.J.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WEINBERGM.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WENIAMINOFFS.D.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WINOGRADOFFA.A.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WINOGRADOFFW.W.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WITH&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WURTZR.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:WYDOOGHEJ.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YAKIMOFFA.-S.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YAKIMOFFW-L&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YAKOBLEW&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YAMANOUCHIT.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YERSINA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YOFH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YVERNAULTA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:YVONP.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ZABOLOTNY&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ZAMMITTH.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z',
#  'https://www.idref.fr/Sru/Solr?q=persname_t:ZUCCARELLI&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z']

# %% [markdown]
# ## 3. Chercher s'il existe au moins une notice associée à l'url idref

# %% [markdown]
# Méthode : pour chaque url chercher la valeur de l'attribut numFound dans l'elt <result>
# \
# `<result name="response" numFound="0" start="0"/>`

# %%
df_contributeurs = df_contributeurs.reindex(columns = df_contributeurs.columns.tolist() + ['Recherche_G-nbr','Recherche_NomPrenom-nbr'])

# %%
for i in range (len(df_contributeurs)):
    for url in df_contributeurs["Recherche_G"]:
    #     print(url)
        r = requests.get(url)
        xml = r.text
        #print(r.text)

        AuteursSoup = BeautifulSoup(xml,'html.parser').b
        
        elt = AuteursSoup.findAll('result'.attrs)
        elt['numFound']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-4fde516176df> in <module>
#       8         AuteursSoup = BeautifulSoup(xml,'html.parser').b
#       9
# ---> 10         elt = AuteursSoup.findAll('result'.attrs)
#      11         elt['numFound']
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
soup = BeautifulSoup(results)
takeaways = soup.findAll('node')

for eachtakeaway in takeaways:
    another_tag = eachtakeaway('tag')
    for tag_attrs in another_tag:
        if str(tag_attrs['k']) == 'cuisine':
            print str(tag_attrs['v'])

# %%
import lxml.html
import requests

url =  'https://www.idref.fr/Sru/Solr?q=persname_t:ALARYA.&sort=score%20desc&version=2.2&start=0&rows=30&indent=on&fl=id,ppn_z,recordtype_z:h,affcourt_z'
response = requests.get(url, stream=True)
response.raw.decode_content = True
tree = lxml.html.parse(response.raw)

# %%
tree.findall("result")
# Out:
# []
