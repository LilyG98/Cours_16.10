# %%
import re

# %%
with open ("BSPETableAnalytique1914.txt","r") as bspetable:
    Table = bspetable.read()
    
    #REtirer les numéros de page: 
    Table = re.sub(r'(\d(, )?){1,5}',"", Table)
    #Retirer tous les détails de 
    Table=re.sub(r'( )?– .*',"",Table)
    print(Table)
# Out:
# Abcès amibien du foie avec bacilles de Koch
# Actinomycose humaine au Pérou
# Afrique
#
#
# Agama colonorum. Parasité par les phlébotomes
#
# Aïnhum. Anatomie pathologique et pathogénie
#
# Alcoolisme en Afrique
#
# Alexine. Action de quelques substances médicamenteuses
# sur le pouvoir alexique du sérum
# Algérie. Microbiologie des conjonctivites
#
#
#
#
#
#
# Coccobacillus acridiorum
#
#
# Allocution du Président
# Ambocepteurs et arsénobenzol
# Amibiase et émétine
#
# Anaphylaxie et hémoglobinuries
# Anaplasma des hématies de mammifères ; signification
# Anémie splénique infantile de cause inconnue
# Âne. Trypanosomiase au Turkestan
# Anguille. Absence de kystes de Carini
# Ankylostome à la Guadeloupe
# Annam. Rhizopus pathogène de l’homme
# Anoplocephala manubriata n. de l’éléphant d’Asie
# Antilles. Photographies concernant les maladies exotiques
#
# Antilope (Tragelaphus scriptus). Larve de porocéphale
# Arachnides. Récolte du venin
# ...

# %%
with open ("BSPETableAnalytique1914.txt","r") as bspetable:
    for line in bspetable:
        print(line)
# Out:
# Abcès amibien du foie avec bacilles de Koch 475
#
# Actinomycose humaine au Pérou 380
#
# Afrique
#
#  – Alcoolisme 258, 362
#
#  – (voir aussi Congo, etc.)
#
# Agama colonorum. Parasité par les phlébotomes 83
#
#  – Filaire et microfilaire 121
#
# Aïnhum. Anatomie pathologique et pathogénie 371
#
#  – au Ouadaï 525
#
# Alcoolisme en Afrique 258, 362
#
#  – Analyse d’échantillons de spiritueux 136, 137
#
# Alexine. Action de quelques substances médicamenteuses
#
# sur le pouvoir alexique du sérum 626
#
# Algérie. Microbiologie des conjonctivites 18
#
# – (Troisième cas de kala-azar en -) 42
#
# – Mélanodermie physiologique des muqueuses 216
#
# – Parasitisme intestinal chez les Arabes du Tell 301
#
# – Importation en France des moutons 506
#
# – Champignons des Teignes 554
#
# – Destruction du Stauronotus maroccanus par le
#
# Coccobacillus acridiorum 651
#
# – Phlébotomes 660
#
# – Infection par les piroplasmes de bovins 699
#
# Allocution du Président 4, 649
#
# ...

# %%
re.search(r'\n – (.)',TableAnalytique_BSPE)
# Out:
# <re.Match object; span=(89, 94), match='\n – A'>
