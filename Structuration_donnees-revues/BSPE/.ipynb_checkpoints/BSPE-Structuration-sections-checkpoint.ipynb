# %% [markdown]
# ## Ce notebook sert à tout simplement à ajouter au tableau des articles du BSPE une colonne qui distingue la catégorie de l'article
#
#
# La particularité de ce notebook est que l'on s'occupe ici de merger 2 dataframes :
#
# 1. Celui que j'ai constitué il y a déjà un bon moment à partir des documents sur <a href = "https://pathexo.societe-mtsi.fr/1844-sommaire-bulletin.html"> le site de la Société Francophone de Médecine Tropicale et Santé Internationale </a> qui s'arrête en 1921
#
# 2. Le df fourni par les responsables de Medica où l'on trouve beaucoup plus d'informations.
#
#
# * Communication
# * Mémoires
# * Discussion
# * Conférences
# * Vie-SPE (Nécrologie, Discours d'ouverture, Correspondances)
# * Société de Médecine de l'OUest Africain
# * Société des sciences médecinales de Madagascar

# %%
import requests
import csv
import pandas as pd
import re

# %% [markdown]
# ## DF MEDICA

# %%
with open ("MEDICA-BSPE.tsv") as BSPE_Medica:
    print(type(BSPE_Medica))
    df_Medica = pd.read_csv(BSPE_Medica,sep='\t')
# Out:
# <class '_io.TextIOWrapper'>

# %%
df_Medica
# Out:
#        Unnamed: 0       cote  refimg page pagecle  \
# 0               0  bspex1908      20    8     NaN
# 1               1  bspex1908      19    7     NaN
# 2               2  bspex1908      18    6     NaN
# 3               3  bspex1908      17    5     NaN
# 4               4  bspex1908      16    4     NaN
# ...           ...        ...     ...  ...     ...
# 55555       55555  bspex1909     522  512     NaN
# 55556       55556  bspex1909     523  513     NaN
# 55557       55557  bspex1909     524  514     NaN
# 55558       55558  bspex1909     525  515       O
# 55559       55559  bspex1909     526  516     NaN
#
#                                                 chapitre pagimgcle pagimg  \
# 0                              Séance du 22 janvier 1908       NaN    NaN
# 1                              Séance du 22 janvier 1908       NaN    NaN
# 2                              Séance du 22 janvier 1908       NaN    NaN
# 3                              Séance du 22 janvier 1908       NaN    NaN
# 4                              Séance du 22 janvier 1908       NaN    NaN
# ...                                                  ...       ...    ...
# 55555  Séance du 13 octobre 1909. Présidence de M. La...       NaN      O
# 55556  Séance du 13 octobre 1909. Présidence de M. La...       NaN    NaN
# 55557  Séance du 13 octobre 1909. Présidence de M. La...       NaN    NaN
# 55558                                     Ouvrages reçus       NaN    NaN
# 55559                                     Ouvrages reçus       NaN    NaN
#
#                                  pagimgtxt pagimgtxtcom
# 0                                      NaN          NaN
# 1                                      NaN          NaN
# 2                                      NaN          NaN
# 3                                      NaN          NaN
# 4                                      NaN          NaN
# ...                                    ...          ...
# 55555  Hémogregaeine de Gongylus ocellatus          NaN
# 55556                                  NaN          NaN
# 55557                                  NaN          NaN
# 55558                                  NaN          NaN
# 55559                                  NaN          NaN
#
# [55560 rows x 10 columns]

# %%
#je retire la colonne"Unnamed": 
df_Medica.drop('Unnamed: 0',
  axis='columns', inplace=True)

# %%
#Ajout du article-id qui permettra de merger avec df-perso

#Nouvelle colonne pour l'article-id : 
df_Medica["article_id"] = df_Medica.apply(lambda _: '', axis=1)

#Nouvelle colonne pour l'année : 
df_Medica["revue_annee"] = df_Medica.apply(lambda _: '', axis=1)

list(df_Medica.columns)

#Réorganisation des colonnes pour mettre en avant article_id, page,chapitre, année qui sont les éléments que je retrouve dans mon df_preso 
df_Medica = df_Medica[['cote',
 'article_id',
 'page',
 'chapitre',
 'revue_annee',
 'pagecle',
 'refimg',
 'pagimgcle',
 'pagimg',
 'pagimgtxt',
 'pagimgtxtcom']]

# %%
for i in range (len(df_Medica)):
    #Extraction de l'année : 
    df_Medica.iloc[i,4] = re.search(r'\d{4}',df_Medica.iloc[i,0]).group(0)
    
    #Constitution de l'article_id
    df_Medica.iloc[i,1] = "BSPE-"+df_Medica.iloc[i,4]+"-"+df_Medica.iloc[i,2]

# %%
df_Medica
# Out:
#             cote     article_id page  \
# 0      bspex1908    BSPE-1908-8    8
# 1      bspex1908    BSPE-1908-7    7
# 2      bspex1908    BSPE-1908-6    6
# 3      bspex1908    BSPE-1908-5    5
# 4      bspex1908    BSPE-1908-4    4
# ...          ...            ...  ...
# 55555  bspex1909  BSPE-1909-512  512
# 55556  bspex1909  BSPE-1909-513  513
# 55557  bspex1909  BSPE-1909-514  514
# 55558  bspex1909  BSPE-1909-515  515
# 55559  bspex1909  BSPE-1909-516  516
#
#                                                 chapitre revue_annee pagecle  \
# 0                              Séance du 22 janvier 1908        1908     NaN
# 1                              Séance du 22 janvier 1908        1908     NaN
# 2                              Séance du 22 janvier 1908        1908     NaN
# 3                              Séance du 22 janvier 1908        1908     NaN
# 4                              Séance du 22 janvier 1908        1908     NaN
# ...                                                  ...         ...     ...
# 55555  Séance du 13 octobre 1909. Présidence de M. La...        1909     NaN
# 55556  Séance du 13 octobre 1909. Présidence de M. La...        1909     NaN
# 55557  Séance du 13 octobre 1909. Présidence de M. La...        1909     NaN
# 55558                                     Ouvrages reçus        1909       O
# 55559                                     Ouvrages reçus        1909     NaN
#
#        refimg pagimgcle pagimg                            pagimgtxt  \
# 0          20       NaN    NaN                                  NaN
# 1          19       NaN    NaN                                  NaN
# 2          18       NaN    NaN                                  NaN
# 3          17       NaN    NaN                                  NaN
# 4          16       NaN    NaN                                  NaN
# ...       ...       ...    ...                                  ...
# 55555     522       NaN      O  Hémogregaeine de Gongylus ocellatus
# 55556     523       NaN    NaN                                  NaN
# 55557     524       NaN    NaN                                  NaN
# 55558     525       NaN    NaN                                  NaN
# 55559     526       NaN    NaN                                  NaN
#
#       pagimgtxtcom
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 55555          NaN
# 55556          NaN
# 55557          NaN
# 55558          NaN
# 55559          NaN
#
# [55560 rows x 11 columns]

# %%
df_Medica_court = df_Medica[["article_id","chapitre"]]

# %%
df_Medica_court
# Out:
#           article_id                                           chapitre
# 0        BSPE-1908-8                          Séance du 22 janvier 1908
# 1        BSPE-1908-7                          Séance du 22 janvier 1908
# 2        BSPE-1908-6                          Séance du 22 janvier 1908
# 3        BSPE-1908-5                          Séance du 22 janvier 1908
# 4        BSPE-1908-4                          Séance du 22 janvier 1908
# ...              ...                                                ...
# 55555  BSPE-1909-512  Séance du 13 octobre 1909. Présidence de M. La...
# 55556  BSPE-1909-513  Séance du 13 octobre 1909. Présidence de M. La...
# 55557  BSPE-1909-514  Séance du 13 octobre 1909. Présidence de M. La...
# 55558  BSPE-1909-515                                     Ouvrages reçus
# 55559  BSPE-1909-516                                     Ouvrages reçus
#
# [55560 rows x 2 columns]

# %%
if type(df_Medica) is pd.core.frame.DataFrame:
    print ("df")
# Out:
# df

# %% [markdown]
# ## DF PERSO*

# %%
with open ("Entrees_BSPE-1921.tsv") as BSPE:
    df_perso = pd.read_csv(BSPE,sep='\t')

# %%
df_perso
# Out:
#       Unnamed: 0   article_id                                  article_auteur  \
# 0              0     BSPE-1-1                              LAVERAN (Alphonse)
# 1              1    BSPE-1-15                           MARTIN (Louis), DARRÉ
# 2              2    BSPE-1-18                                   SERGENT (ED.)
# 3              3    BSPE-1-22                                    REMY (F. J.)
# 4              4    BSPE-1-25         SERGENT(ED.),SERGENT(ÉT.), LEDOUX (ED.)
# ...          ...          ...                                             ...
# 2438        2438  BSPE-14-662                                    ROUBAUD (E.)
# 2439        2439  BSPE-14-666                           JOUVEAU-DUBREUIL (H.)
# 2440        2440  BSPE-14-685  DONATIEN (A.), SERGENT (ED., ET.), PARROT (L.)
# 2441        2441  BSPE-14-710                                     LAVIER (G.)
# 2442        2442  BSPE-14-717              LAIGRET, OUZILLEAU (F.), LEFROU ()
#
#                                           article_titre  article_page  \
# 0                                 Discours d’ouverture.             1
# 1     Sur les symptômes nerveux du début de la malad...            15
# 2     La fièvre méditerranéenne en Algérie. Note pré...            18
# 3                    Le Debab dans la région de Barika.            22
# 4     Le Debab dans la région de la Zousfana (SudOra...            25
# ...                                                 ...           ...
# 2438  Le bien-être dans le Paludisme et les maladies...           662
# 2439                           Le Béribéri au Setchouan           666
# 2440      Le Paludisme en Corse. Etude épidémiologique.           685
# 2441  Flagellés parasites intestinaux du campagnol i...           710
# 2442   Contribution à l’étude de l 'Onchocerca volvulus           717
#
#       revue_annee  revue_numero
# 0            1908             1
# 1            1908             1
# 2            1908             1
# 3            1908             1
# 4            1908             1
# ...           ...           ...
# 2438         1921            14
# 2439         1921            14
# 2440         1921            14
# 2441         1921            14
# 2442         1921            14
#
# [2443 rows x 7 columns]

# %%
#Retirer la colonne"Unnamed":
df_perso.drop('Unnamed: 0',
  axis='columns', inplace=True)

# %%
#Nouvelle colonne pour la section : 
df_perso["article_section"] = df_perso.apply(lambda _: '', axis=1)

# print("ancien ordre colonnes : \n\n", list(df_perso.columns))

df_perso = df_perso[['article_id',
 'article_auteur', 
 'article_section',
 'article_titre',
 'article_page',
 'revue_annee',
 'revue_numero',]]

#Modification du article_id pour mettre les années plutôt que les numéros (meilleure lisibilité trans-revues)
for i in range (len(df_perso)):
    df_perso.iloc[i,0] = "BSPE-"+str(df_perso.iloc[i,5])+"-"+str(df_perso.iloc[i,4])

# %%
df_perso
# Out:
#          article_id                                  article_auteur  \
# 0       BSPE-1908-1                              LAVERAN (Alphonse)
# 1      BSPE-1908-15                           MARTIN (Louis), DARRÉ
# 2      BSPE-1908-18                                   SERGENT (ED.)
# 3      BSPE-1908-22                                    REMY (F. J.)
# 4      BSPE-1908-25         SERGENT(ED.),SERGENT(ÉT.), LEDOUX (ED.)
# ...             ...                                             ...
# 2438  BSPE-1921-662                                    ROUBAUD (E.)
# 2439  BSPE-1921-666                           JOUVEAU-DUBREUIL (H.)
# 2440  BSPE-1921-685  DONATIEN (A.), SERGENT (ED., ET.), PARROT (L.)
# 2441  BSPE-1921-710                                     LAVIER (G.)
# 2442  BSPE-1921-717              LAIGRET, OUZILLEAU (F.), LEFROU ()
#
#      article_section                                      article_titre  \
# 0                                                 Discours d’ouverture.
# 1                     Sur les symptômes nerveux du début de la malad...
# 2                     La fièvre méditerranéenne en Algérie. Note pré...
# 3                                    Le Debab dans la région de Barika.
# 4                     Le Debab dans la région de la Zousfana (SudOra...
# ...              ...                                                ...
# 2438                  Le bien-être dans le Paludisme et les maladies...
# 2439                                           Le Béribéri au Setchouan
# 2440                      Le Paludisme en Corse. Etude épidémiologique.
# 2441                  Flagellés parasites intestinaux du campagnol i...
# 2442                   Contribution à l’étude de l 'Onchocerca volvulus
#
#       article_page  revue_annee  revue_numero
# 0                1         1908             1
# 1               15         1908             1
# 2               18         1908             1
# 3               22         1908             1
# 4               25         1908             1
# ...            ...          ...           ...
# 2438           662         1921            14
# 2439           666         1921            14
# 2440           685         1921            14
# 2441           710         1921            14
# 2442           717         1921            14
#
# [2443 rows x 7 columns]

# %% [markdown]
# ## Fusionner les deux DF : df_perso et df_Medica_court
#
# Points pour les merge :
# * article_id => On ne conserve que ceux correpsondant à df_perso ! => how='inner' on='article_id'
# * revue_annee

# %%
# df_BSPE_Merged = pd.merge(df_perso,df_Medica_court,
#         how='inner', on='article_id')

df_BSPE_Merged=df_perso.merge(df_Medica_court, how='inner', on='article_id')
df_BSPE_Merged #Ici on a des doublons car 2531 entrées au lieu de 2443...
# Out:
#          article_id                                  article_auteur  \
# 0       BSPE-1908-1                              LAVERAN (Alphonse)
# 1       BSPE-1908-1                              LAVERAN (Alphonse)
# 2      BSPE-1908-15                           MARTIN (Louis), DARRÉ
# 3      BSPE-1908-15                           MARTIN (Louis), DARRÉ
# 4      BSPE-1908-18                                   SERGENT (ED.)
# ...             ...                                             ...
# 2526  BSPE-1921-662                                    ROUBAUD (E.)
# 2527  BSPE-1921-666                           JOUVEAU-DUBREUIL (H.)
# 2528  BSPE-1921-685  DONATIEN (A.), SERGENT (ED., ET.), PARROT (L.)
# 2529  BSPE-1921-710                                     LAVIER (G.)
# 2530  BSPE-1921-717              LAIGRET, OUZILLEAU (F.), LEFROU ()
#
#      article_section                                      article_titre  \
# 0                                                 Discours d’ouverture.
# 1                                                 Discours d’ouverture.
# 2                     Sur les symptômes nerveux du début de la malad...
# 3                     Sur les symptômes nerveux du début de la malad...
# 4                     La fièvre méditerranéenne en Algérie. Note pré...
# ...              ...                                                ...
# 2526                  Le bien-être dans le Paludisme et les maladies...
# 2527                                           Le Béribéri au Setchouan
# 2528                      Le Paludisme en Corse. Etude épidémiologique.
# 2529                  Flagellés parasites intestinaux du campagnol i...
# 2530                   Contribution à l’étude de l 'Onchocerca volvulus
#
#       article_page  revue_annee  revue_numero  \
# 0                1         1908             1
# 1                1         1908             1
# 2               15         1908             1
# 3               15         1908             1
# 4               18         1908             1
# ...            ...          ...           ...
# 2526           662         1921            14
# 2527           666         1921            14
# 2528           685         1921            14
# 2529           710         1921            14
# 2530           717         1921            14
#
#                                                chapitre
# 0                             Séance du 22 janvier 1908
# 1     Table analytique des matières (Tomes I-XXV) dr...
# 2     Séance du 22 janvier 1908. Communications. Sur...
# 3     Arsénobenzènes. - Novarsénobenzol. - Eparséno....
# 4     Séance du 22 janvier 1908. Communications. Sur...
# ...                                                 ...
# 2526  Séance du 14 décembre 1921. Communications. Le...
# 2527  Séance du 14 décembre 1921. Mémoires. Le bérib...
# 2528  Séance du 14 décembre 1921. Mémoires. Le bérib...
# 2529  Séance du 14 décembre 1921. Mémoires. Le palud...
# 2530  Séance du 14 décembre 1921. Mémoires. Flagellé...
#
# [2531 rows x 8 columns]

# %% [markdown]
# ## AJOUT SECTIONS

# %%
Lsection=["Communication","Mémoire","Correspondance","Discours","Presentation"]
for i in range (len(df_BSPE_Merged)):
    for section in Lsection:
        if re.search(section,df_BSPE_Merged.iloc[i,7]):
            df_BSPE_Merged.iloc[i,2]= section
# Out:
# /home/humanum/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_BSPE_Merged
# Out:
#          article_id                                  article_auteur  \
# 0       BSPE-1908-1                              LAVERAN (Alphonse)
# 2      BSPE-1908-15                           MARTIN (Louis), DARRÉ
# 4      BSPE-1908-18                                   SERGENT (ED.)
# 6      BSPE-1908-22                                    REMY (F. J.)
# 8      BSPE-1908-25         SERGENT(ED.),SERGENT(ÉT.), LEDOUX (ED.)
# ...             ...                                             ...
# 2526  BSPE-1921-662                                    ROUBAUD (E.)
# 2527  BSPE-1921-666                           JOUVEAU-DUBREUIL (H.)
# 2528  BSPE-1921-685  DONATIEN (A.), SERGENT (ED., ET.), PARROT (L.)
# 2529  BSPE-1921-710                                     LAVIER (G.)
# 2530  BSPE-1921-717              LAIGRET, OUZILLEAU (F.), LEFROU ()
#
#      article_section                                      article_titre  \
# 0                                                 Discours d’ouverture.
# 2      Communication  Sur les symptômes nerveux du début de la malad...
# 4      Communication  La fièvre méditerranéenne en Algérie. Note pré...
# 6      Communication                 Le Debab dans la région de Barika.
# 8      Communication  Le Debab dans la région de la Zousfana (SudOra...
# ...              ...                                                ...
# 2526   Communication  Le bien-être dans le Paludisme et les maladies...
# 2527         Mémoire                           Le Béribéri au Setchouan
# 2528         Mémoire      Le Paludisme en Corse. Etude épidémiologique.
# 2529         Mémoire  Flagellés parasites intestinaux du campagnol i...
# 2530         Mémoire   Contribution à l’étude de l 'Onchocerca volvulus
#
#       article_page  revue_annee  revue_numero  \
# 0                1         1908             1
# 2               15         1908             1
# 4               18         1908             1
# 6               22         1908             1
# 8               25         1908             1
# ...            ...          ...           ...
# 2526           662         1921            14
# 2527           666         1921            14
# 2528           685         1921            14
# 2529           710         1921            14
# 2530           717         1921            14
#
#                                                chapitre
# 0                             Séance du 22 janvier 1908
# 2     Séance du 22 janvier 1908. Communications. Sur...
# 4     Séance du 22 janvier 1908. Communications. Sur...
# 6     Séance du 22 janvier 1908. Communications. La ...
# 8     Séance du 22 janvier 1908. Communications. Le ...
# ...                                                 ...
# 2526  Séance du 14 décembre 1921. Communications. Le...
# 2527  Séance du 14 décembre 1921. Mémoires. Le bérib...
# 2528  Séance du 14 décembre 1921. Mémoires. Le bérib...
# 2529  Séance du 14 décembre 1921. Mémoires. Le palud...
# 2530  Séance du 14 décembre 1921. Mémoires. Flagellé...
#
# [2375 rows x 8 columns]

# %%
df_BSPE_Merged=df_BSPE_Merged.drop_duplicates(subset="article_id",keep="first")
#Pb : ici j'ai une perte d'informations car seulelemtn 2375 entrées au lieu de 2443 
#=> Surement les discours d'ouverture et nécrologies !!

# %%
df_BSPE_Merged
# Out:
#          article_id                                  article_auteur  \
# 0       BSPE-1908-1                              LAVERAN (Alphonse)
# 2      BSPE-1908-15                           MARTIN (Louis), DARRÉ
# 4      BSPE-1908-18                                   SERGENT (ED.)
# 6      BSPE-1908-22                                    REMY (F. J.)
# 8      BSPE-1908-25         SERGENT(ED.),SERGENT(ÉT.), LEDOUX (ED.)
# ...             ...                                             ...
# 2526  BSPE-1921-662                                    ROUBAUD (E.)
# 2527  BSPE-1921-666                           JOUVEAU-DUBREUIL (H.)
# 2528  BSPE-1921-685  DONATIEN (A.), SERGENT (ED., ET.), PARROT (L.)
# 2529  BSPE-1921-710                                     LAVIER (G.)
# 2530  BSPE-1921-717              LAIGRET, OUZILLEAU (F.), LEFROU ()
#
#      article_section                                      article_titre  \
# 0                                                 Discours d’ouverture.
# 2      Communication  Sur les symptômes nerveux du début de la malad...
# 4      Communication  La fièvre méditerranéenne en Algérie. Note pré...
# 6      Communication                 Le Debab dans la région de Barika.
# 8      Communication  Le Debab dans la région de la Zousfana (SudOra...
# ...              ...                                                ...
# 2526   Communication  Le bien-être dans le Paludisme et les maladies...
# 2527         Mémoire                           Le Béribéri au Setchouan
# 2528         Mémoire      Le Paludisme en Corse. Etude épidémiologique.
# 2529         Mémoire  Flagellés parasites intestinaux du campagnol i...
# 2530         Mémoire   Contribution à l’étude de l 'Onchocerca volvulus
#
#       article_page  revue_annee  revue_numero  \
# 0                1         1908             1
# 2               15         1908             1
# 4               18         1908             1
# 6               22         1908             1
# 8               25         1908             1
# ...            ...          ...           ...
# 2526           662         1921            14
# 2527           666         1921            14
# 2528           685         1921            14
# 2529           710         1921            14
# 2530           717         1921            14
#
#                                                chapitre
# 0                             Séance du 22 janvier 1908
# 2     Séance du 22 janvier 1908. Communications. Sur...
# 4     Séance du 22 janvier 1908. Communications. Sur...
# 6     Séance du 22 janvier 1908. Communications. La ...
# 8     Séance du 22 janvier 1908. Communications. Le ...
# ...                                                 ...
# 2526  Séance du 14 décembre 1921. Communications. Le...
# 2527  Séance du 14 décembre 1921. Mémoires. Le bérib...
# 2528  Séance du 14 décembre 1921. Mémoires. Le bérib...
# 2529  Séance du 14 décembre 1921. Mémoires. Le palud...
# 2530  Séance du 14 décembre 1921. Mémoires. Flagellé...
#
# [2375 rows x 8 columns]

# %% [markdown]
# ## AJOUT SEANCE

# %%
df_BSPE_Merged.to_csv("BSPE_Sections.tsv",sep='\t')

# %%
#Nouvelle colonne pour la séance : 
df_BSPE_Merged["article_SPE_seance"] = df_perso.apply(lambda _: '', axis=1)

dateSeance = r'Séance du (\d{1,2} \D+ \d{4})\.'
for i in range (len(df_BSPE_Merged)):
    if re.search(dateSeance,df_BSPE_Merged.iloc[i,7]):
        seance=re.search(dateSeance,df_BSPE_Merged.iloc[i,7])
        df_BSPE_Merged.iloc[i,8] = seance.group(1)

# %%
df_BSPE_Merged
# Out:
#          article_id                                  article_auteur  \
# 0       BSPE-1908-1                              LAVERAN (Alphonse)
# 2      BSPE-1908-15                           MARTIN (Louis), DARRÉ
# 4      BSPE-1908-18                                   SERGENT (ED.)
# 6      BSPE-1908-22                                    REMY (F. J.)
# 8      BSPE-1908-25         SERGENT(ED.),SERGENT(ÉT.), LEDOUX (ED.)
# ...             ...                                             ...
# 2526  BSPE-1921-662                                    ROUBAUD (E.)
# 2527  BSPE-1921-666                           JOUVEAU-DUBREUIL (H.)
# 2528  BSPE-1921-685  DONATIEN (A.), SERGENT (ED., ET.), PARROT (L.)
# 2529  BSPE-1921-710                                     LAVIER (G.)
# 2530  BSPE-1921-717              LAIGRET, OUZILLEAU (F.), LEFROU ()
#
#      article_section                                      article_titre  \
# 0                                                 Discours d’ouverture.
# 2      Communication  Sur les symptômes nerveux du début de la malad...
# 4      Communication  La fièvre méditerranéenne en Algérie. Note pré...
# 6      Communication                 Le Debab dans la région de Barika.
# 8      Communication  Le Debab dans la région de la Zousfana (SudOra...
# ...              ...                                                ...
# 2526   Communication  Le bien-être dans le Paludisme et les maladies...
# 2527         Mémoire                           Le Béribéri au Setchouan
# 2528         Mémoire      Le Paludisme en Corse. Etude épidémiologique.
# 2529         Mémoire  Flagellés parasites intestinaux du campagnol i...
# 2530         Mémoire   Contribution à l’étude de l 'Onchocerca volvulus
#
#       article_page  revue_annee  revue_numero  \
# 0                1         1908             1
# 2               15         1908             1
# 4               18         1908             1
# 6               22         1908             1
# 8               25         1908             1
# ...            ...          ...           ...
# 2526           662         1921            14
# 2527           666         1921            14
# 2528           685         1921            14
# 2529           710         1921            14
# 2530           717         1921            14
#
#                                                chapitre article_SPE_seance
# 0                             Séance du 22 janvier 1908
# 2     Séance du 22 janvier 1908. Communications. Sur...    22 janvier 1908
# 4     Séance du 22 janvier 1908. Communications. Sur...    22 janvier 1908
# 6     Séance du 22 janvier 1908. Communications. La ...    22 janvier 1908
# 8     Séance du 22 janvier 1908. Communications. Le ...    22 janvier 1908
# ...                                                 ...                ...
# 2526  Séance du 14 décembre 1921. Communications. Le...   14 décembre 1921
# 2527  Séance du 14 décembre 1921. Mémoires. Le bérib...   14 décembre 1921
# 2528  Séance du 14 décembre 1921. Mémoires. Le bérib...   14 décembre 1921
# 2529  Séance du 14 décembre 1921. Mémoires. Le palud...   14 décembre 1921
# 2530  Séance du 14 décembre 1921. Mémoires. Flagellé...   14 décembre 1921
#
# [2375 rows x 9 columns]

# %%
df_BSPE_Merged['article_section']=='Communication'
# Out:
# 0       False
# 2        True
# 4        True
# 6        True
# 8        True
#         ...
# 2526     True
# 2527    False
# 2528    False
# 2529    False
# 2530    False
# Name: article_section, Length: 2375, dtype: bool

# %%
ParSection = df_BSPE_Merged.groupby("article_section").count()

# %%
df2=df_BSPE_Merged.filter(["revue_annee","article_section"],axis=1)
