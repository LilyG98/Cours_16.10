# %%
import requests
import csv
import pandas as pd
import re

# %%
with open ("AHMC_articles-originaux_Termine.tsv") as BSPE:
    df = pd.read_csv(BSPE,sep='\t')

# %%
df
# Out:
#       Unnamed: 0   article_id           article_auteur  \
# 0            0.0    AHMC-01-9                   Clarac
# 1            2.0  AHMC-01-114              Fontaine(1)
# 2            3.0  AHMC-01-129                 Calmette
# 3            4.0  AHMC-01-135            Kermorgant. A
# 4            5.0  AHMC-01-143               J-C Baurac
# ...          ...          ...                      ...
# 1822       157.0  AHMC-38-107              A. Herivaux
# 1823       174.0  AHMC-38-161                V. Reynes
# 1824       175.0  AHMC-38-174  H. Floch ; E. Abonnenc
# 1825       176.0  AHMC-38-183      Grosfilez ; Lefèvre
# 1826       177.0  AHMC-38-360                      NaN
#
#                                          article_détail  \
# 0                                       Première partie
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
df["article_auteur"]
# Out:
# 0                        Clarac
# 1                   Fontaine(1)
# 2                      Calmette
# 3                 Kermorgant. A
# 4                    J-C Baurac
#                  ...
# 1822                A. Herivaux
# 1823                  V. Reynes
# 1824    H. Floch ; E. Abonnenc
# 1825        Grosfilez ; Lefèvre
# 1826                        NaN
# Name: article_auteur, Length: 1827, dtype: object
